# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib import request
from urllib.request import urlopen
import os.path
import nltk 
import re 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
list=[]
list1=[]
url='https://www.memphis.edu/'
def doc(url):
    response = requests.get(url)
    return response.text
dm = doc(url)
soup = BeautifulSoup(dm, 'html.parser')
for link in soup.find_all('a',attrs={'href': re.compile("^https://")}):
    
    l=link.get('href') 
    list.append(l)
print(sum)
count=0
loop=0
for i in range(len(list)):
    url1=list[i]
    response = requests.get(url1)
    text=response.text
    soup1 = BeautifulSoup(text, 'html.parser')
    for link1 in soup1.find_all('a',attrs={'href': re.compile("^https://")}):
        l1=link1.get('href') 
        list1.append(l1)
        count+=1
        loop+=1
        print(l1)
    if loop>10000:     
        break
    else:
        pass
        
    
print(count)
print(loop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAMESH~1\AppData\Local\Temp/ipykernel_11604/3039697706.py in <module>
#       5     response = requests.get(url)
#       6     return response.text
# ----> 7 dm = doc(url)
#       8 soup = BeautifulSoup(dm, 'html.parser')
#       9 for link in soup.find_all('a',attrs={'href': re.compile("^https://")}):
#
# C:\Users\RAMESH~1\AppData\Local\Temp/ipykernel_11604/3039697706.py in doc(url)
#       3 url='https://www.memphis.edu/'
#       4 def doc(url):
# ----> 5     response = requests.get(url)
#       6     return response.text
#       7 dm = doc(url)
#
# NameError: name 'requests' is not defined

# %%
for m in range(2):
    tf=['https://www.memphis.edu/admissions/international/index.php']
    lm=WordNetLemmatizer()
    try:
        for lines in urlopen(list1[m]):
            
            s=re.sub('[^a-zA-Z]',' ',str(lines))
            s=s.lower()
            s=s.split()
            s=[lm.lemmatize(word) for word in s if word not in stopwords.words('english')]
            s=' '.join(s)
            tf.append(s)
        save_pth = r'fs1/'
        filenm = "file"+str(m)+".txt"
        n = os.path.join(save_pth, filenm)
        f = open(n, "w")
        f.write(str(tf))
        f.close()
    except:
        print(tf)
# Out:
# ['https://www.memphis.edu/admissions/international/index.php', 'b doctype html n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b n', 'b lt ie html lang en class j lt ie lt ie lt ie endif n', 'b ie html lang en class j lt ie lt ie endif n', 'b ie html lang en class j lt ie endif n', 'b gt ie html lang en class j endif n', 'b n', 'b n', 'b n', 'b head n', 'b meta http equiv content type content text html charset utf n', 'b script function w l w l w l w l push gtm start n', 'b new date gettime event gtm j var f getelementsbytagname n', 'b j createelement dl l datalayer l l j async true j src n', 'b http www googletagmanager com gtm j id dl f parentnode insertbefore j f n', 'b window document script datalayer gtm sx nq script meta charset utf n', 'b title prospective student n', 'b twhat local n', 'b university memphis n', 'b title n', 'b meta name description content prospective student uofm experience memphis uofm tiger sport rich campus life excel academic producti
# ...

# %%
import nltk
import re 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
a = """style border none background transparent color fff title search uofm button label ham search span class sr search span label form id hide menu class toggle menu px ml hide menu href x div n', 'b div class flex mt n', 'b ul class nav hamburger menu left flex column text right pt pr n', 'b li class nav item class nav link href http www memphis edu prospective index php prospective student li n', 'b li class nav item class nav link href http www memphis edu student index php current student li n', 'b li class nav item class nav link href http www memphis edu umparents index php parent amp family li n', 'b li class nav item class nav link href http alumnus memphis edu start aspx gid amp pgid target blank rel noopener alumnus li n', 'b li class nav item class nav link href http www memphis edu veteran index php veteran li n', 'b li class nav item class nav link href http www memphis edu fac staff index php faculty amp staff li n', 'b ul n', 'b nav class nav hamburger menu right flex column pl n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false academic n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title thing academic href http www memphis edu academic index php onclick taglink topnav dropdownacademics allthingsacademics thing academic li n', 'b li class nav item title college amp school href http www memphis edu academic college school php onclick taglink topnav dropdownacademics collegesschools college amp school li n', 'b li class nav item title uofm global online degree program href http www memphis edu uofmglobal index php onclick taglink topnav dropdownacademics uofmglobal uofm global online degree program li n', 'b li class nav item title uofm lambuth jackson tn href http www memphis edu lambuth index php onclick taglink topnav dropdownacademics uofmlambuth uofm lambuth jackson tn li n', 'b li class nav item class secondary acalog ug title undergraduate catalog href catalog memphis edu onclick taglink topnav dropdownacademics undergraduatecatalog undergraduate catalog li n', 'b li class nav item class secondary acalog g title graduate catalog href catalog memphis edu onclick taglink topnav dropdownacademics graduatecatalog graduate catalog li n', 'b li class nav item title academic calendar href http www memphis edu registrar calendar index php onclick taglink topnav dropdownacademics academiccalendar academic calendar li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false admission n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title undergraduate student href http www memphis edu admission index old php aria label apply undergraduate admission onclick taglink topnav dropdownadmissions undergraduatestudents undergraduate li n', 'b li class nav item title graduate student href http www memphis edu graduateadmissions index php aria label apply graduate admission onclick taglink topnav dropdownadmissions graduatestudents graduate li n', 'b li class nav item title uofm global online href http www memphis edu uofmglobal admission index php aria label apply uofm global online admission onclick taglink topnav dropdownadmissions uofmglobal uofm global online li n', 'b li class nav item title law school href http www memphis edu law admission index php aria label apply law admission onclick taglink topnav dropdownadmissions lawschool law school li n', 'b li class nav item title international href http www memphis edu admission international index php aria label apply international admission onclick taglink topnav dropdownadmissions international international li n', 'b li class nav item title transfer student href http www memphis edu admission transfer index php aria label transfer student onclick taglink topnav dropdownadmissions transferstudents transfer student li n', 'b li class nav item title virtual tour href http www memphis edu admission virtualtour php aria label virtual tour onclick taglink topnav dropdownadmissions virtualtour virtual tour li n', 'b li class nav item title fee tuition href http www memphis edu usbs fee index php aria label fee tuition onclick taglink topnav dropdownadmissions feestuition fee tuition li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false research innovation n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title division research innovation href http www memphis edu research index php aria label division research innovation onclick taglink topnav dropdownresearch divisionresearchinnovation division research innovation li n', 'b li class nav item title researcher href http www memphis edu research researcher index php aria label researcher onclick taglink topnav dropdownresearch forresearchers researcher li n', 'b li class nav item title industry partner href http www memphis edu research industry index php aria label industry partner onclick taglink topnav dropdownresearch industrypartners industry partner li n', 'b li class nav item title center institute href http www memphis edu research facility center institute php aria label center institute onclick taglink topnav dropdownresearch centersinstitutes center institute li n', 'b li class nav item title fedex institute technology href http www memphis edu fedex index php aria label fedex institute technology onclick taglink topnav dropdownresearch fit fedex institute technology li n', 'b li class nav item title office institutional research href http www memphis edu oir index php aria label office institutional research onclick taglink topnav dropdownresearch oir office institutional research li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false library n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title university library href http www memphis edu library index php aria label university library onclick taglink topnav dropdownlibraries universitylibraries university library li n', 'b li class nav item title research resource href http www memphis edu library resource index php aria label research resource onclick taglink topnav dropdownlibraries researchresources research resource li n', 'b li class nav item title special collection href http www memphis edu library special collection index php aria label special collection onclick taglink topnav dropdownlibraries specialcollections special collection li n', 'b li class nav item title ask librarian href http www memphis edu library help askalibrarian php aria label ask librarian onclick taglink topnav dropdownlibraries asklibrarian ask librarian li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false athletics n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title tiger athletics href http www memphis edu athletics index php aria label tiger athletics onclick taglink topnav dropdownathletics tigerathletics tiger athletics li n', 'b li class nav item title ticket href http gotigersgo evenue net cgi bin ncommerce segetgrouplist groupcode amp linkid memphis amp shoppercontext amp caller amp appcode target blank rel noopener aria label ticket onclick taglink topnav dropdownathletics ticket ticket li n', 'b li class nav item title intramurals href http www memphis edu campusrec sport index php aria label intramurals onclick taglink topnav dropdownathletics intramurals intramurals li n', 'b li class nav item title campus rec href http www memphis edu campusrec index php aria label campus rec onclick taglink topnav dropdownathletics campusrec campus rec li n', 'b li class nav item title make gift href http www memphis edu tsf index php aria label make gift onclick taglink topnav dropdownathletics makegift make gift li n', 'b li class nav item title gotigersgo com href http gotigersgo com target blank rel noopener aria label gotigersgo com onclick taglink topnav dropdownathletics gotigersgo gotigersgo com li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false support uofm n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title make gift href http www memphis edu development index php aria label make gift onclick taglink topnav dropdownsupport makegift make gift li n', 'b li class nav item title alumnus association href http alumnus memphis edu start aspx gid amp pgid target blank rel noopener aria label alumnus association onclick taglink topnav dropdownsupport alumniassociation alumnus association li n', 'b li class nav item title athletics development href http www memphis edu tsf index php aria label athletics development onclick taglink topnav dropdownsupport athleticsdevelopment athletics development li n', 'b li class nav item title corporate amp foundation relation href http www memphis edu cfr index php aria label corporate amp foundation relation onclick taglink topnav dropdownsupport corporatefoundationrelations corporate amp foundation relation li n', 'b ul n', 'b div n', 'b div n', 'b div class btn group flex column class nav link dropdown toggle role button href data toggle dropdown aria haspopup true aria expanded false news amp event n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item title tiger zone student event href http memphis campuslabs com engage event target blank rel noopener aria label tiger zone student event onclick taglink topnav dropdownnewsevents tigerzone tiger zone student event li n', 'b li class nav item title campus event href http www memphis edu calendar aria label campus event onclick taglink topnav dropdownnewsevents campusevents campus event li n', 'b li class nav item title medium room news amp magazine href http www memphis edu mediaroom index php aria label medium room news amp magazine onclick taglink topnav dropdownnewsevents mediaroom medium room news amp magazine li n', 'b ul n', 'b div n', 'b div n', 'b nav div n', 'b div n', 'b div n', 'b end xhtml hamburger xhtml n', 'b n', 'b header n', 'b begin alert n', 'b n', 'b n', 'b div class header alert style background color c e n', 'b div class container n', 'b div class row n', 'b div n', 'b div class header alert wrapper n', 'b div class header alert wrapper icon sm nbsp div n', 'b div class header alert wrapper text role region aria label uofm alert style color ffffff title uofm alert href http www memphis edu coronavirusupdates onmouseover style color onmouseout style color fff border bottom px dotted onblur style color fff border bottom px dotted onfocus style color review covid info amp campus update gt div n', 'b div n', 'b div n', 'b div n', 'b div n', 'b div n', 'b n', 'b n', 'b end alert n', 'b n', 'b n', 'b begin homepage header xhtml n', 'b ie n', 'b p class browserupgrade using strong outdated strong browser please href http browsehappy com upgrade browser improve experience security p n', 'b endif n', 'b div id hamburger menu class hamburger menu bg blue p p md n', 'b div class container fluid n', 'b div class flex justify content end n', 'b form role search class mt action http umwa memphis edu search search php method post n', 'b input type search class search type text name search id ham search placeholder search aria label search n', 'b input type hidden name type id site value page n', 'b button type submit id searchbutton title search uofm span class fa fa search fa x span button n', 'b label ham search span class sr search span label n', 'b form n', 'b href class toggle menu px ml hide menu id hide menu x n', 'b div n', 'b div class flex mt n', 'b ul class nav hamburger menu left flex column text right pt pr n', 'b li class nav item n', 'b href class nav link prospective student n', 'b li n', 'b li class nav item n', 'b href class nav link current student n', 'b li n', 'b li class nav item n', 'b href class nav link parent amp family n', 'b li n', 'b li class nav item n', 'b href class nav link alumnus n', 'b li n', 'b li class nav item n', 'b href class nav link veteran n', 'b li n', 'b li class nav item n', 'b href class nav link faculty amp staff n', 'b li n', 'b ul n', 'b nav class nav hamburger menu right flex column pl n', 'b div class btn group flex column n', 'b class nav link dropdown toggle data toggle dropdown href role button n', 'b aria haspopup true aria expanded false admission n', 'b div class dropdown menu n', 'b ul class nav flex flex column pl n', 'b li class nav item href http www memphis edu admission title admission information onclick taglink topnav dropdownadmissions admissionsinformation admission n', 'b information li n', 'b li class nav item href http www memphis edu admission freshman apply ugrd php aria label apply undergraduate admission title undergraduate student onclick taglink topnav dropdownadmissions undergraduatestudents undergraduate n', 'b student li n', 'b li class nav item href http www memphis edu graduateadmissions future apply grad php aria label apply graduate admission title graduate student onclick taglink topnav dropdownadmissions graduatestudents graduate n', 'b student li n', 'b li class nav item href http www memphis edu law adm"""
tf=[]
sen=nltk.sent_tokenize(a)
lm=WordNetLemmatizer()
for i in range(len(sen)):
    s= nltk.word_tokenize(sen[i])
    #s=re.sub('[^a-zA-Z]','', s)
    #s=s.lower()
    #s=s.split()
    s=[lm.lemmatize(word) for word in s if word not in stopwords.words('english')]
    s=' '.join(s)
    tf.append(s)

# %%
tf
# Out:
# ["style border none background transparent color fff title search uofm button label ham search span class sr search span label form id hide menu class toggle menu px ml hide menu href x div n ' , ' b div class flex mt n ' , ' b ul class nav hamburger menu left flex column text right pt pr n ' , ' b li class nav item class nav link href http www memphis edu prospective index php prospective student li n ' , ' b li class nav item class nav link href http www memphis edu student index php current student li n ' , ' b li class nav item class nav link href http www memphis edu umparents index php parent amp family li n ' , ' b li class nav item class nav link href http alumnus memphis edu start aspx gid amp pgid target blank rel noopener alumnus li n ' , ' b li class nav item class nav link href http www memphis edu veteran index php veteran li n ' , ' b li class nav item class nav link href http www memphis edu fac staff index php faculty amp staff li n ' , ' b ul n ' , ' b nav class nav
# ...
